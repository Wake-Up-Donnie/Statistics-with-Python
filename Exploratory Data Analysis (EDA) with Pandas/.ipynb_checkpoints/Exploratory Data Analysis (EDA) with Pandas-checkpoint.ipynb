# %% [markdown]
# ## Exploratory Data Analysis (EDA) with Pandas

# %%
# %load_ext sql
#https://www.kaggle.com/benhamner/sf-bay-area-bike-share
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///bikeshare.db
# Out:
# 'Connected: None@bikeshare.db'

# %%
trips_table = %sql SELECT * FROM trip;
# Out:
# Done.

# %%
import pandas as pd

# %%
trips = trips_table.DataFrame()

# %%
print (trips)
# Out:
#             id  duration       start_date  \
# 0         4069       174   8/29/2013 9:08
# 1         4073      1067   8/29/2013 9:24
# 2         4074      1131   8/29/2013 9:24
# 3         4075      1117   8/29/2013 9:24
# 4         4076      1118   8/29/2013 9:25
# 5         4078      3829   8/29/2013 9:31
# 6         4079       995   8/29/2013 9:35
# 7         4080       764   8/29/2013 9:36
# 8         4081       218   8/29/2013 9:38
# 9         4084       287   8/29/2013 9:41
# 10        4086       178   8/29/2013 9:42
# 11        4100      1392   8/29/2013 9:57
# 12        4116      1213  8/29/2013 10:11
# 13        4121      1040  8/29/2013 10:13
# 14        4123       500  8/29/2013 10:14
# 15        4125       464  8/29/2013 10:14
# 16        4130        71  8/29/2013 10:16
# 17        4132      3637  8/29/2013 10:17
# 18        4133      1965  8/29/2013 10:17
# 19        4134       574  8/29/2013 10:19
# 20        4135      3492  8/29/2013 10:19
# ...

# %% [raw]
# Question One
# Load the trips table into a dataframe.
# Make 4 extra columns from the start_date column (We will use these in later questions):
# month would contain only the month component
# dayofweek would indicate what day of the week the date is
# date would contain only the date component
# hour would only contain the hour component Hint to deal with datetime objects in pandas

# %%
import datetime as dt
trips.dtypes
trips['start_date'] = pd.to_datetime(trips['start_date'],infer_datetime_format=True)
trips['month'] = pd.DatetimeIndex(trips['start_date']).month
trips['dayofweek'] = pd.DatetimeIndex(trips['start_date']).day
trips['date'] = pd.DatetimeIndex(trips['start_date']).date
trips['hour'] = pd.DatetimeIndex(trips['start_date']).hour
trips['year'] = pd.DatetimeIndex(trips['start_date']).year
trips = trips[trips.year == 2013]
print (trips)
# Out:
#             id  duration          start_date  \
# 0         4069       174 2013-08-29 09:08:00
# 1         4073      1067 2013-08-29 09:24:00
# 2         4074      1131 2013-08-29 09:24:00
# 3         4075      1117 2013-08-29 09:24:00
# 4         4076      1118 2013-08-29 09:25:00
# 5         4078      3829 2013-08-29 09:31:00
# 6         4079       995 2013-08-29 09:35:00
# 7         4080       764 2013-08-29 09:36:00
# 8         4081       218 2013-08-29 09:38:00
# 9         4084       287 2013-08-29 09:41:00
# 10        4086       178 2013-08-29 09:42:00
# 11        4100      1392 2013-08-29 09:57:00
# 12        4116      1213 2013-08-29 10:11:00
# 13        4121      1040 2013-08-29 10:13:00
# 14        4123       500 2013-08-29 10:14:00
# 15        4125       464 2013-08-29 10:14:00
# 16        4130        71 2013-08-29 10:16:00
# 17        4132      3637 2013-08-29 10:17:00
# 18        4133      1965 2013-08-29 10:17:00
# 19        4134       574 2013-08-29 10:19:00
# ...

# %% [raw]
# Group the bike rides by month and count the number of users per month.
# Plot the number of users for each month.
# What do you observe? Provide a likely explanation to your observation. Real life data can often be messy/incomplete and cursory EDA is often able to reveal that.

# %%
riders_by_mont = trips.groupby(['month'])
#df = pd.DataFrame(riders_by_month['id'].count())
#print (df)
riders_per_month = trips['month'].value_counts()
df = pd.DataFrame(riders_per_month).sort_index()
df = df.reset_index()
df = df.rename(columns = {'index':'month', 'month':'number of riders'})
print (df)
# Out:
#    month  number of riders
# 0      8              2102
# 1      9             25243
# 2     10             29105
# 3     11             24219
# 4     12             19894

# %%
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
sns.pointplot(x='month', y='number of riders', data =df)

# %%
trips.isnull().values.ravel().sum()

# %% [raw]
# There is a drastic drop in the number of users during the Winter months. I can guess that this is becuase of the cold weather.

# %% [raw]
# Plot the daily user count from September to December. Mark the mean and mean +/- 1.5 * Standard Deviation as horizontal lines on the plot. This would help you identify the outliers in your data. Describe your observations. image

# %%
#df_sept_dec = df.iloc[8:12,:]
#print (df_sept_dec)
#riders_by_mont = trips.groupby(['month'])
df_trips_sep_dec = trips[(trips.month >= 9) & (trips.month <= 12)]
##date_index_df = pd.DataFrame(df_trips_sep_dec)
##date_index_df['date'] = pd.to_datetime(date_index_df.date)
##date_index_df= date_index_df.set_index(pd.DatetimeIndex(date_index_df['date']))
#print (date_index_df)
##date_index_df.resample("1d").sum().fillna(0).rolling(window=3, min_periods=1).mean()
#print (date_index_df)
day_count = df_trips_sep_dec["date"].value_counts()
#print (day_count)
df_trips_sep_dec_count_with_date = pd.DataFrame(day_count).sort_index()
#print (df3)
df_trips_sep_dec_count_with_date = df_trips_sep_dec_count_with_date.reset_index()
df_trips_sep_dec_count_with_date = df_trips_sep_dec_count_with_date.rename(columns = {'index':'date', 'date':'number of riders'})
# Out:
#             id  duration          start_date  \
# 2102      7442      1508 2013-09-01 00:11:00
# 2103      7443      1513 2013-09-01 00:12:00
# 2104      7444      1345 2013-09-01 00:19:00
# 2105      7445       931 2013-09-01 00:21:00
# 2106      7446       159 2013-09-01 00:23:00
# 2107      7447      1033 2013-09-01 00:24:00
# 2108      7448       323 2013-09-01 00:29:00
# 2109      7449       825 2013-09-01 00:38:00
# 2110      7450       819 2013-09-01 00:38:00
# 2111      7452       759 2013-09-01 00:54:00
# 2112      7454       238 2013-09-01 01:01:00
# 2113      7457       175 2013-09-01 01:09:00
# 2114      7458       447 2013-09-01 02:01:00
# 2115      7459      1124 2013-09-01 02:04:00
# 2116      7460      1259 2013-09-01 02:04:00
# 2117      7461       194 2013-09-01 02:09:00
# 2118      7463       609 2013-09-01 02:19:00
# 2119      7465        87 2013-09-01 02:27:00
# 2120      7466     39751 2013-09-01 04:06:00
# 2121      7467       783 2013-09-01 05:24:00
# ...

# %%
sns.pointplot(x='date', y='number of riders', data =df_trips_sep_dec_count_with_date)

# %%
from math import sqrt
import numpy as np
average_daily_trips = np.mean(df_trips_sep_dec_count_with_date['number of riders'])
print (average_daily_trips)
strd_dev_plus_1_5 = (average_daily_trips + 1.5 * df_trips_sep_dec_count_with_date['number of riders'].std())
print (strd_dev_plus_1_5)
strd_dev_minus_1_5 = (average_daily_trips - 1.5 * df_trips_sep_dec_count_with_date['number of riders'].std())
print (strd_dev_minus_1_5)
# Out:
# 807.057377049
# 1238.25675996
# 375.857994141

# %%
import matplotlib.pyplot as plt
# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 5)
matplotlib.style.use('ggplot')
fig,ax = plt.subplots()
data_line = ax.plot(df_trips_sep_dec_count_with_date['date'],df_trips_sep_dec_count_with_date['number of riders'], label='number of riders', marker='o')
mean_line = ax.plot(df_trips_sep_dec_count_with_date['date'],np.zeros_like(df_trips_sep_dec_count_with_date['date']) + average_daily_trips ,label='Mean', linestyle='--',color='g')
strd_above_line = ax.plot(df_trips_sep_dec_count_with_date['date'],np.zeros_like(df_trips_sep_dec_count_with_date['date']) + strd_dev_plus_1_5 ,label='mean + 1.5 * strd dev', linestyle='--', color='r')
strd_below_line = ax.plot(df_trips_sep_dec_count_with_date['date'],np.zeros_like(df_trips_sep_dec_count_with_date['date']) + strd_dev_minus_1_5 ,label='mean - 1.5 * strd dev', linestyle='--',color='b')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0., title = "Number of Riders 2013: Sept - Dec")
plt.xlabel('Date')
plt.ylabel('Number of Riders')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# You can see the number of riders reduces on wekeends and also you can see that the number of users start to decrease starting in Mid November

# %% [raw]
# Plot the distribution of the daily user counts for all months as a histogram. Comment on the distribution you see and explain why the distribution might be shaped as such.

# %%
riders_by_month = trips.groupby(['month'])
riders_month_df = pd.DataFrame(riders_by_month['id'].count())
riders_month_df = riders_month_df.reset_index()
riders_month_df = riders_month_df.rename(columns = {'id':'Number of Riders'})
print (riders_month_df)
ax = sns.barplot(x='month', y ='Number of Riders', data=riders_month_df)
ax.set_title("Number of Riders per Month")
# Out:
#    month  Number of Riders
# 0      8              2102
# 1      9             25243
# 2     10             29105
# 3     11             24219
# 4     12             19894

# %% [raw]
# I believe that not much data was collected in August so that is why there is a low count there. When Winter comes there is a decrease in riders because it is colder out so not as many people want to ride outside.

# %% [raw]
# Now we are going to explore hourly trends of user activity. Group the bike rides by date and hour and count the number of rides in the given hour on the given date. Make a boxplot of the hours in the day (x) against the number of users (y) in that given hour.

# %%
date_hour = trips.groupby(['date','hour'])
date_hour_df = pd.DataFrame(date_hour['id'].count())
date_hour_df = date_hour_df.reset_index()
date_hour_df = date_hour_df.rename(columns ={'id':'Number of Riders'})
print (date_hour_df)
# Out:
#             date  hour  Number of Riders
# 0     2013-08-29     9                12
# 1     2013-08-29    10                14
# 2     2013-08-29    11                42
# 3     2013-08-29    12               120
# 4     2013-08-29    13                87
# 5     2013-08-29    14                50
# 6     2013-08-29    15                62
# 7     2013-08-29    16                61
# 8     2013-08-29    17                88
# 9     2013-08-29    18                68
# 10    2013-08-29    19                59
# 11    2013-08-29    20                36
# 12    2013-08-29    21                25
# 13    2013-08-29    22                20
# 14    2013-08-29    23                 4
# 15    2013-08-30     0                 1
# 16    2013-08-30     1                 1
# 17    2013-08-30     2                 2
# 18    2013-08-30     3                 1
# 19    2013-08-30     5                 2
# 20    2013-08-30     6                 8
# 21    2013-08-30     7                14
# ...

# %%
ax = sns.boxplot(x="hour", y="Number of Riders", data=date_hour_df)
ax.set_title("Riders per Hour")

# %% [raw]
# Replot the boxplot in 6. after binning your data into weekday and weekend. Describe the differences you observe between hour user activity between weekday and weekend?

# %%
trips['day of week'] = trips['start_date'].dt.weekday
date_hour = trips.groupby(['date','hour', 'day of week'])
date_hour_df = pd.DataFrame(date_hour['id'].count())
date_hour_df = date_hour_df.reset_index()
date_hour_df = date_hour_df.rename(columns ={'id':'Number of Riders'})
criteria = date_hour_df['day of week'].map( lambda x: x==5 or x ==6)
weekends = date_hour_df[criteria]
ax = sns.boxplot(x='hour', y="Number of Riders", data=weekends)
ax.set_title("Weekend Riders per Hour")

# %%
criteria = date_hour_df['day of week'].map( lambda x: x<5)
weekends = date_hour_df[criteria]
ax = sns.boxplot(x='hour', y="Number of Riders", data=weekends)
ax.set_title("Weekday Riders per Hour")

# %% [raw]
# You can see that on Weekdays the most amont of riders is at 8am when people go to work and 5pm when people get off of work. In comparing the weekend riders and weekday riders you can see that there are less riders on the weekend and there seems to be only one spike at noon, most likely when people get lunch. Weekends and weekdays are simillar in that from around 11pm - 5am there is not many riders.
